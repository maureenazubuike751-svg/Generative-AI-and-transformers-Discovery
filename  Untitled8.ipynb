# %%
# GENERATIVE AI & TRANSFORMERS - COMPLETE SUBMISSION

# !pip install transformers torch -q

from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
import torch

print("=" * 60)
print("GENERATIVE AI & TRANSFORMERS - COMPLETE SUBMISSION")
print("=" * 60)

# ============================================
# SETUP PIPELINES
# ============================================

print("\n🔄 Loading models...")

# Sentiment
sentiment_pipeline = pipeline("sentiment-analysis")

# Text Generation
generation_pipeline = pipeline("text-generation", model="gpt2")

# Summarization (manual to avoid errors)
model_name = "facebook/bart-large-cnn"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

def summarize(text, max_length=50, min_length=20):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=1024)
    summary_ids = model.generate(inputs["input_ids"], max_length=max_length, min_length=min_length, do_sample=False)
    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)

print("✅ All models ready!\n")
print("=" * 60)

# ============================================
# SENTIMENT ANALYSIS (6 sentences)
# ============================================

print("\n📊 SENTIMENT ANALYSIS RESULTS")
print("-" * 50)

sentences = [
    "I absolutely love this product!",
    "This is the worst experience ever.",
    "The movie was okay, nothing special.",
    "Oh great, another meeting.",
    "I'm so excited for the weekend!",
    "This traffic is making me furious."
]

for text in sentences:
    result = sentiment_pipeline(text)[0]
    print(f"Text: {text}")
    print(f"Sentiment: {result['label']} (Confidence: {result['score']:.2f})")
    print("-" * 40)

# ============================================
# TEXT GENERATION
# ============================================

print("\n📝 TEXT GENERATION")
print("-" * 50)

prompt = "The future of artificial intelligence"
generated = generation_pipeline(prompt, max_length=50, do_sample=True, temperature=0.8)
print(generated[0]['generated_text'])
print("-" * 50)

# ============================================
# SUMMARIZATION
# ============================================

print("\n📄 SUMMARIZATION")
print("-" * 50)

article = """Hospitals are using AI to analyze medical images, predict patient outcomes,
and streamline administrative tasks. Recent studies show that AI algorithms
can detect certain types of cancer with accuracy comparable to human radiologists
in some cases. However, experts caution that AI should be used to assist,
not replace, healthcare professionals. Integrating AI into healthcare systems
requires careful planning, robust data privacy concerns, and the need for
continuous validation. Despite these challenges, the potential benefits include
faster diagnoses, personalized treatment plans, and reduced healthcare costs."""

print("Original Article:")
print(article)
print("\n" + "-" * 50)

print("\n📌 Short Summary (30 tokens):")
print(summarize(article, max_length=30, min_length=10))

print("\n📌 Medium Summary (50 tokens):")
print(summarize(article, max_length=50, min_length=20))

print("\n📌 Long Summary (100 tokens):")
print(summarize(article, max_length=100, min_length=50))

# ============================================
# OBSERVATIONS
# ============================================

print("\n" + "=" * 60)
print("📝 OBSERVATIONS")
print("=" * 60)

print("""
🔍 SENTIMENT ANALYSIS:
- The model handles clear positive/negative sentences well.
- Sarcasm detection failed: 'Oh great, another meeting' was classified as POSITIVE.
- This shows the model lacks nuance and can misinterpret tone.

🔍 TEXT GENERATION:
- The model produced coherent text but included unverified claims.
- This is a known issue called 'hallucination' – generating plausible but false information.

🔍 SUMMARIZATION:
- Short summary (30 tokens): Concise but loses important details.
- Medium summary (50 tokens): Best balance of clarity and completeness.
- Long summary (100 tokens): More detailed but slightly repetitive.

💡 CONCLUSION:
- AI models are powerful but not perfect.
- Always need human oversight for critical decisions.
- Best used as assistive tools, not replacements for human judgment.
""")

print("=" * 60)
print("✅ PROJECT COMPLETE")
print("=" * 60)
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# GENERATIVE AI & TRANSFORMERS - COMPLETE SUBMISSION
# ...
#
# 🔄 Loading models...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# ...
